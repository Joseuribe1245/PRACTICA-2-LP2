# %%
import json
data = {}

data['Negocios de articulos'] = []

data['Negocios de articulos'].append({
    'articulo_electronico':'Celular',
    'cantidad':35
})
data['Negocios de articulos'].append({
    'articulo_electronico':'Tablet',
    'cantidad':25
})
data['Negocios de articulos'].append({
    'articulo_electronico':'Laptop',
    'cantidad':25
})
data['Negocios de articulos'].append({
    'articulo_electronico':'Cámara',
    'cantidad':20
})
data['Negocios de articulos'].append({
    'articulo_electronico':'Computadora',
    'cantidad':14
})
data['Negocios de articulos'].append({
    'articulo_electronico':'Televisor',
    'cantidad':10
})
data['Negocios de articulos'].append({
    'articulo_electronico':'PS3',
    'cantidad':15
})
data['Negocios de articulos'].append({
    'articulo_electronico':'Mouse',
    'cantidad':30
})
data['Negocios de articulos'].append({
    'articulo_electronico':'Impresora',
    'cantidad':14
})
data['Negocios de articulos'].append({
    'articulo_electronico':'Nintendo Switch',
    'cantidad':18
})
data['Negocios de articulos'].append({
    'articulo_electronico':'Airpods',
    'cantidad':26
})
data['Negocios de articulos'].append({
    'articulo_electronico':'Apple watch',
    'cantidad':19
})
data['Negocios de articulos'].append({
    'articulo_electronico':'ipad',
    'cantidad':16
})
data['Negocios de articulos'].append({
    'articulo_electronico':'PS4',
    'cantidad':15
})
data['Negocios de articulos'].append({
    'articulo_electronico':'Drones',
    'cantidad':26
})
#print(data)

data_string = json.dumps(data)
decoded = json.loads(data_string)

for i in range(15):
    print('hay'+' '+str(decoded['Negocios de articulos'][i]['cantidad'])+' '+str(decoded['Negocios de articulos'][i]['articulo_electronico']))
# Out:
# hay 35 Celular
# hay 25 Tablet
# hay 25 Laptop
# hay 20 Cámara
# hay 14 Computadora
# hay 10 Televisor
# hay 15 PS3
# hay 30 Mouse
# hay 14 Impresora
# hay 18 Nintendo Switch
# hay 26 Airpods
# hay 19 Apple watch
# hay 16 ipad
# hay 15 PS4
# hay 26 Drones
